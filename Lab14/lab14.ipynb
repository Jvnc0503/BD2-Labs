# %%
# %pip install pymongo requests pandas
# Out:
# Collecting pymongo
#   Downloading pymongo-4.13.2-cp313-cp313-win_amd64.whl.metadata (22 kB)
# Collecting requests
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pandas in c:\program files\python313\lib\site-packages (2.3.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\program files\python313\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\program files\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\program files\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pymongo-4.13.2-cp313-cp313-win_amd64.whl (955 kB)
#    ---------------------------------------- 0.0/955.1 kB ? eta -:--:--
#    --------------------------------------- 955.1/955.1 kB 10.0 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
# Installing collected packages: urllib3, idna, dnspython, charset_normalizer, certifi, requests, pymongo
#
#    ---------------------------------------- 0/7 [urllib3]
#    ---------------------------------------- 0/7 [urllib3]
#    ---------------------------------------- 0/7 [urllib3]
#    ---------------------------------------- 0/7 [urllib3]
#    ---------------------------------------- 0/7 [urllib3]
#    ----- ---------------------------------- 1/7 [idna]
#    ----- ---------------------------------- 1/7 [idna]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------- ---------------------------- 2/7 [dnspython]
#    ----------------- ---------------------- 3/7 [charset_normalizer]
#    ----------------- ---------------------- 3/7 [charset_normalizer]
#    ---------------------- ----------------- 4/7 [certifi]
#    ---------------------------- ----------- 5/7 [requests]
#    ---------------------------- ----------- 5/7 [requests]
#    ---------------------------- ----------- 5/7 [requests]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------- ----- 6/7 [pymongo]
#    ---------------------------------------- 7/7 [pymongo]
#
# Successfully installed certifi-2025.6.15 charset_normalizer-3.4.2 dnspython-2.7.0 idna-3.10 pymongo-4.13.2 requests-2.32.4 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient
import requests
from bson.json_util import dumps
import json
import os
import pandas as pd

# %%
class MongoDBHandler:
    def __init__(self):
        self.mongo_uri = (
            "mongodb://localhost:27017/"
        )
        self.db_name = "text_analysis"
        self.drake_path = "./drake_lyrics/drake_data.json"
        self.milei_path = "./milei_news"
        self.connect_mongo()

    def connect_mongo(self):
        try:
            client = MongoClient(self.mongo_uri)
            self.db = client[self.db_name] if client else None
            print(f"Conectado a la base de datos '{self.db_name}' en MongoDB.")
        except Exception as e:
            print(f"Error al conectar a MongoDB: {e}")

    def insert_drake(self):
        with open(self.drake_path, "r") as file:
            js = json.load(file)
            try:
                self.db.drake_lyrics.insert_many(js)
                print("Inserted drake lyrics data")
            except Exception as e:
                print("Error when inserting drake data", e)

    def insert_milei(self):
        if not os.path.exists(self.milei_path):
            print("Milei data does not exist")
            return
        
        ctr: int = 0
        for root, dirs, files in os.walk(self.milei_path):
            for file in files:
                path = os.path.join(root, file)
                with open (path, "r") as json_file:
                    try:
                        doc = json.load(json_file)
                        self.db.milei_news.insert_one(doc)
                        print(f"Inserted document {ctr}")
                    except Exception as e:
                        print(f"Error when inserting document {ctr}", e)
                ctr += 1

            
    def create_indexes(self):
        self.db.drake_lyrics.create_index({"lyrics": "text"})
        self.db.milei_news.create_index({"title": "text", "summary": "text"})

    def drake_love_money(self):
        pass

    def milei_title_inflacion(self):
        pass

    def milei_summary_milei_dolar_not_inflacion(self):
        pass

# %%
handler = MongoDBHandler()

handler.insert_drake()
handler.insert_milei()
handler.create_indexes()
# Out:
# Conectado a la base de datos 'text_analysis' en MongoDB.
# Inserted drake lyrics data
# Error when inserting document 0 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 1 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 2 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 3 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 4 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 5 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 6 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 7 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 8
# Error when inserting document 9 Extra data: line 10 column 2 (char 527)
# Inserted document 10
# Error when inserting document 11 Extra data: line 10 column 2 (char 527)
# Inserted document 12
# Error when inserting document 13 Extra data: line 10 column 2 (char 627)
# Error when inserting document 14 Extra data: line 10 column 2 (char 627)
# Inserted document 15
# Error when inserting document 16 Extra data: line 10 column 2 (char 627)
# Error when inserting document 17 Extra data: line 10 column 2 (char 627)
# Error when inserting document 18 Extra data: line 10 column 2 (char 627)
# Inserted document 19
# Error when inserting document 20 Extra data: line 10 column 2 (char 627)
# Error when inserting document 21 Extra data: line 10 column 2 (char 627)
# Error when inserting document 22 Extra data: line 10 column 2 (char 627)
# Error when inserting document 23 Extra data: line 10 column 2 (char 627)
# Error when inserting document 24 Extra data: line 10 column 2 (char 627)
# Error when inserting document 25 Extra data: line 10 column 2 (char 543)
# Error when inserting document 26 Extra data: line 10 column 2 (char 543)
# Error when inserting document 27 Extra data: line 10 column 2 (char 543)
# Inserted document 28
# Error when inserting document 29 Extra data: line 10 column 2 (char 543)
# Inserted document 30
# Error when inserting document 31 Extra data: line 10 column 2 (char 543)
# Error when inserting document 32 Extra data: line 10 column 2 (char 543)
# Error when inserting document 33 Extra data: line 10 column 2 (char 543)
# Error when inserting document 34 Extra data: line 10 column 2 (char 543)
# Error when inserting document 35 Extra data: line 10 column 2 (char 543)
# Error when inserting document 36 Extra data: line 10 column 2 (char 543)
# Error when inserting document 37 Extra data: line 10 column 2 (char 543)
# Inserted document 38
# Error when inserting document 39 Extra data: line 10 column 2 (char 543)
# Error when inserting document 40 Extra data: line 10 column 2 (char 543)
# Error when inserting document 41 Extra data: line 10 column 2 (char 543)
# Error when inserting document 42 Extra data: line 10 column 2 (char 543)
# Inserted document 43
# Error when inserting document 44 Extra data: line 10 column 2 (char 543)
# Inserted document 45
# Inserted document 46
# Error when inserting document 47 Extra data: line 10 column 2 (char 543)
# Error when inserting document 48 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 49 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 50 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 51 Extra data: line 10 column 2 (char 510)
# Inserted document 52
# Error when inserting document 53 Extra data: line 10 column 2 (char 587)
# Inserted document 54
# Error when inserting document 55 Extra data: line 10 column 2 (char 701)
# Error when inserting document 56 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 57 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 58 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 59 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 60 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 61 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 62 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 63 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 64
# Error when inserting document 65 Extra data: line 10 column 2 (char 686)
# Inserted document 66
# Error when inserting document 67 Extra data: line 10 column 2 (char 582)
# Error when inserting document 68 Extra data: line 10 column 2 (char 746)
# Inserted document 69
# Inserted document 70
# Error when inserting document 71 Extra data: line 10 column 2 (char 664)
# Error when inserting document 72 Extra data: line 10 column 2 (char 626)
# Inserted document 73
# Error when inserting document 74 Extra data: line 10 column 2 (char 567)
# Error when inserting document 75 Extra data: line 10 column 2 (char 567)
# Error when inserting document 76 Extra data: line 10 column 2 (char 677)
# Error when inserting document 77 'charmap' codec can't decode byte 0x8d in position 304: character maps to <undefined>
# Error when inserting document 78 Extra data: line 10 column 2 (char 785)
# Inserted document 79
# Inserted document 80
# Error when inserting document 81 Extra data: line 10 column 2 (char 606)
# Error when inserting document 82 Extra data: line 10 column 2 (char 604)
# Error when inserting document 83 Extra data: line 10 column 2 (char 604)
# Error when inserting document 84 'charmap' codec can't decode byte 0x9d in position 150: character maps to <undefined>
# Error when inserting document 85 'charmap' codec can't decode byte 0x9d in position 150: character maps to <undefined>
# Error when inserting document 86 'charmap' codec can't decode byte 0x9d in position 150: character maps to <undefined>
# Error when inserting document 87 Extra data: line 10 column 2 (char 669)
# Error when inserting document 88 Extra data: line 10 column 2 (char 669)
# Error when inserting document 89 Extra data: line 10 column 2 (char 574)
# Error when inserting document 90 Extra data: line 10 column 2 (char 574)
# Error when inserting document 91 Extra data: line 10 column 2 (char 582)
# Error when inserting document 92 Extra data: line 10 column 2 (char 582)
# Error when inserting document 93 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 94 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 95
# Error when inserting document 96 Extra data: line 10 column 2 (char 440)
# Error when inserting document 97 Extra data: line 10 column 2 (char 575)
# Inserted document 98
# Error when inserting document 99 Extra data: line 10 column 2 (char 548)
# Error when inserting document 100 Extra data: line 10 column 2 (char 548)
# Error when inserting document 101 Extra data: line 10 column 2 (char 548)
# Inserted document 102
# Error when inserting document 103 Extra data: line 10 column 2 (char 588)
# Inserted document 104
# Error when inserting document 105 Extra data: line 10 column 2 (char 588)
# Error when inserting document 106 Extra data: line 10 column 2 (char 588)
# Error when inserting document 107 Extra data: line 10 column 2 (char 588)
# Error when inserting document 108 Extra data: line 10 column 2 (char 610)
# Error when inserting document 109 Extra data: line 10 column 2 (char 610)
# Error when inserting document 110 Extra data: line 10 column 2 (char 610)
# Error when inserting document 111 Extra data: line 10 column 2 (char 610)
# Error when inserting document 112 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 113 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 114 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 115 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 116 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 117 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 118 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 119 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 120
# Error when inserting document 121 Extra data: line 10 column 2 (char 568)
# Inserted document 122
# Error when inserting document 123 Extra data: line 10 column 2 (char 481)
# Error when inserting document 124 Extra data: line 10 column 2 (char 425)
# Error when inserting document 125 Extra data: line 10 column 2 (char 481)
# Error when inserting document 126 Extra data: line 10 column 2 (char 475)
# Error when inserting document 127 Extra data: line 10 column 2 (char 559)
# Inserted document 128
# Error when inserting document 129 Extra data: line 10 column 2 (char 557)
# Error when inserting document 130 Extra data: line 10 column 2 (char 645)
# Error when inserting document 131 Extra data: line 10 column 2 (char 551)
# Inserted document 132
# Error when inserting document 133 Extra data: line 10 column 2 (char 660)
# Error when inserting document 134 Extra data: line 10 column 2 (char 507)
# Error when inserting document 135 Extra data: line 10 column 2 (char 524)
# Error when inserting document 136 Extra data: line 10 column 2 (char 655)
# Error when inserting document 137 Extra data: line 10 column 2 (char 551)
# Inserted document 138
# Error when inserting document 139 Extra data: line 10 column 2 (char 591)
# Error when inserting document 140 Extra data: line 10 column 2 (char 626)
# Error when inserting document 141 Extra data: line 10 column 2 (char 576)
# Error when inserting document 142 Extra data: line 10 column 2 (char 575)
# Inserted document 143
# Error when inserting document 144 Extra data: line 10 column 2 (char 538)
# Error when inserting document 145 Extra data: line 10 column 2 (char 712)
# Error when inserting document 146 Extra data: line 10 column 2 (char 623)
# Error when inserting document 147 Extra data: line 10 column 2 (char 637)
# Error when inserting document 148 Extra data: line 10 column 2 (char 653)
# Error when inserting document 149 Extra data: line 10 column 2 (char 689)
# Error when inserting document 150 Extra data: line 10 column 2 (char 654)
# Inserted document 151
# Error when inserting document 152 Extra data: line 10 column 2 (char 594)
# Inserted document 153
# Error when inserting document 154 Extra data: line 10 column 2 (char 555)
# Error when inserting document 155 Extra data: line 10 column 2 (char 535)
# Inserted document 156
# Error when inserting document 157 Extra data: line 10 column 2 (char 606)
# Inserted document 158
# Inserted document 159
# Error when inserting document 160 Extra data: line 10 column 2 (char 611)
# Error when inserting document 161 Extra data: line 10 column 2 (char 526)
# Error when inserting document 162 Extra data: line 10 column 2 (char 591)
# Error when inserting document 163 Extra data: line 10 column 2 (char 611)
# Error when inserting document 164 Extra data: line 10 column 2 (char 527)
# Error when inserting document 165 Extra data: line 10 column 2 (char 564)
# Inserted document 166
# Inserted document 167
# Inserted document 168
# Inserted document 169
# Inserted document 170
# Error when inserting document 171 Extra data: line 10 column 2 (char 576)
# Error when inserting document 172 Extra data: line 10 column 2 (char 618)
# Error when inserting document 173 Extra data: line 10 column 2 (char 618)
# Error when inserting document 174 Extra data: line 10 column 2 (char 685)
# Error when inserting document 175 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 176 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 177 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 178 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 179 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 180 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 181 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 182
# Error when inserting document 183 Extra data: line 10 column 2 (char 575)
# Error when inserting document 184 Extra data: line 10 column 2 (char 488)
# Error when inserting document 185 Extra data: line 10 column 2 (char 432)
# Error when inserting document 186 Extra data: line 10 column 2 (char 488)
# Error when inserting document 187 Extra data: line 10 column 2 (char 482)
# Error when inserting document 188 Extra data: line 10 column 2 (char 518)
# Inserted document 189
# Error when inserting document 190 Extra data: line 10 column 2 (char 564)
# Error when inserting document 191 Extra data: line 10 column 2 (char 652)
# Error when inserting document 192 Extra data: line 10 column 2 (char 558)
# Error when inserting document 193 Extra data: line 10 column 2 (char 667)
# Error when inserting document 194 Extra data: line 10 column 2 (char 514)
# Error when inserting document 195 Extra data: line 10 column 2 (char 531)
# Error when inserting document 196 Extra data: line 10 column 2 (char 662)
# Error when inserting document 197 Extra data: line 10 column 2 (char 558)
# Inserted document 198
# Error when inserting document 199 Extra data: line 10 column 2 (char 633)
# Inserted document 200
# Error when inserting document 201 Extra data: line 10 column 2 (char 582)
# Inserted document 202
# Inserted document 203
# Inserted document 204
# Error when inserting document 205 'charmap' codec can't decode byte 0x8d in position 311: character maps to <undefined>
# Error when inserting document 206 Extra data: line 10 column 2 (char 792)
# Error when inserting document 207 Extra data: line 10 column 2 (char 696)
# Error when inserting document 208 Extra data: line 10 column 2 (char 661)
# Inserted document 209
# Error when inserting document 210 Extra data: line 10 column 2 (char 693)
# Error when inserting document 211 Extra data: line 10 column 2 (char 562)
# Inserted document 212
# Inserted document 213
# Inserted document 214
# Inserted document 215
# Error when inserting document 216 Extra data: line 10 column 2 (char 618)
# Error when inserting document 217 Extra data: line 10 column 2 (char 533)
# Inserted document 218
# Error when inserting document 219 Extra data: line 10 column 2 (char 618)
# Inserted document 220
# Error when inserting document 221 Extra data: line 10 column 2 (char 571)
# Inserted document 222
# Inserted document 223
# Inserted document 224
# Inserted document 225
# Error when inserting document 226 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 227 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 228
# Error when inserting document 229 Extra data: line 10 column 2 (char 582)
# Error when inserting document 230 Extra data: line 10 column 2 (char 582)
# Inserted document 231
# Error when inserting document 232 Extra data: line 10 column 2 (char 574)
# Inserted document 233
# Error when inserting document 234 Extra data: line 10 column 2 (char 574)
# Error when inserting document 235 Extra data: line 10 column 2 (char 546)
# Error when inserting document 236 Extra data: line 10 column 2 (char 546)
# Inserted document 237
# Inserted document 238
# Error when inserting document 239 Extra data: line 10 column 2 (char 632)
# Error when inserting document 240 Extra data: line 10 column 2 (char 589)
# Error when inserting document 241 Extra data: line 10 column 2 (char 566)
# Error when inserting document 242 Extra data: line 10 column 2 (char 497)
# Inserted document 243
# Inserted document 244
# Inserted document 245
# Error when inserting document 246 Extra data: line 10 column 2 (char 528)
# Error when inserting document 247 Extra data: line 10 column 2 (char 603)
# Error when inserting document 248 Extra data: line 10 column 2 (char 603)
# Inserted document 249
# Error when inserting document 250 Extra data: line 10 column 2 (char 519)
# Error when inserting document 251 'charmap' codec can't decode byte 0x9d in position 959: character maps to <undefined>
# Error when inserting document 252 'charmap' codec can't decode byte 0x9d in position 364: character maps to <undefined>
# Error when inserting document 253 'charmap' codec can't decode byte 0x9d in position 364: character maps to <undefined>
# Inserted document 254
# Error when inserting document 255 Extra data: line 10 column 2 (char 620)
# Error when inserting document 256 Extra data: line 10 column 2 (char 585)
# Error when inserting document 257 Extra data: line 10 column 2 (char 585)
# Inserted document 258
# Inserted document 259
# Inserted document 260
# Error when inserting document 261 Extra data: line 10 column 2 (char 587)
# Inserted document 262
# Error when inserting document 263 Extra data: line 10 column 2 (char 531)
# Error when inserting document 264 Extra data: line 10 column 2 (char 531)
# Inserted document 265
# Error when inserting document 266 Extra data: line 10 column 2 (char 675)
# Inserted document 267
# Error when inserting document 268 Extra data: line 10 column 2 (char 598)
# Error when inserting document 269 Extra data: line 10 column 2 (char 598)
# Error when inserting document 270 Extra data: line 10 column 2 (char 707)
# Inserted document 271
# Inserted document 272
# Inserted document 273
# Error when inserting document 274 'charmap' codec can't decode byte 0x9d in position 1031: character maps to <undefined>
# Error when inserting document 275 'charmap' codec can't decode byte 0x9d in position 454: character maps to <undefined>
# Inserted document 276
# Error when inserting document 277 Extra data: line 10 column 2 (char 596)
# Error when inserting document 278 Extra data: line 10 column 2 (char 663)
# Error when inserting document 279 Extra data: line 10 column 2 (char 663)
# Error when inserting document 280 Extra data: line 10 column 2 (char 491)
# Error when inserting document 281 Extra data: line 10 column 2 (char 544)
# Error when inserting document 282 Extra data: line 10 column 2 (char 574)
# Error when inserting document 283 Extra data: line 10 column 2 (char 608)
# Inserted document 284
# Error when inserting document 285 Extra data: line 10 column 2 (char 512)
# Inserted document 286
# Error when inserting document 287 Extra data: line 10 column 2 (char 528)
# Inserted document 288
# Error when inserting document 289 Extra data: line 16 column 2 (char 750)
# Inserted document 290
# Error when inserting document 291 Extra data: line 16 column 2 (char 720)
# Inserted document 292
# Error when inserting document 293 Extra data: line 10 column 2 (char 491)
# Inserted document 294
# Error when inserting document 295 Extra data: line 16 column 2 (char 668)
# Error when inserting document 296 Extra data: line 16 column 2 (char 743)
# Inserted document 297
# Inserted document 298
# Error when inserting document 299 Extra data: line 16 column 2 (char 668)
# Inserted document 300
# Error when inserting document 301 'charmap' codec can't decode byte 0x9d in position 576: character maps to <undefined>
# Error when inserting document 302 'charmap' codec can't decode byte 0x9d in position 576: character maps to <undefined>
# Inserted document 303
# Inserted document 304
# Inserted document 305
# Inserted document 306
# Inserted document 307
# Inserted document 308
# Inserted document 309
# Error when inserting document 310 Extra data: line 16 column 2 (char 741)
# Error when inserting document 311 Extra data: line 16 column 2 (char 677)
# Inserted document 312
# Inserted document 313
# Inserted document 314
# Error when inserting document 315 Extra data: line 16 column 2 (char 632)
# Inserted document 316
# Inserted document 317
# Error when inserting document 318 Extra data: line 16 column 2 (char 786)
# Error when inserting document 319 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 320 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 321 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 322 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 323 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 324 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 325
# Inserted document 326
# Error when inserting document 327 Extra data: line 10 column 2 (char 578)
# Error when inserting document 328 Extra data: line 10 column 2 (char 581)
# Error when inserting document 329 Extra data: line 10 column 2 (char 617)
# Inserted document 330
# Error when inserting document 331 Extra data: line 10 column 2 (char 617)
# Error when inserting document 332 Extra data: line 10 column 2 (char 473)
# Error when inserting document 333 Extra data: line 10 column 2 (char 586)
# Error when inserting document 334 Extra data: line 10 column 2 (char 555)
# Inserted document 335
# Error when inserting document 336 Extra data: line 10 column 2 (char 550)
# Inserted document 337
# Inserted document 338
# Inserted document 339
# Error when inserting document 340 Extra data: line 10 column 2 (char 570)
# Error when inserting document 341 Extra data: line 10 column 2 (char 650)
# Inserted document 342
# Inserted document 343
# Error when inserting document 344 Extra data: line 10 column 2 (char 520)
# Inserted document 345
# Error when inserting document 346 Extra data: line 10 column 2 (char 652)
# Inserted document 347
# Error when inserting document 348 Extra data: line 10 column 2 (char 530)
# Inserted document 349
# Inserted document 350
# Inserted document 351
# Inserted document 352
# Error when inserting document 353 Extra data: line 10 column 2 (char 551)
# Error when inserting document 354 Extra data: line 10 column 2 (char 587)
# Error when inserting document 355 Extra data: line 10 column 2 (char 510)
# Inserted document 356
# Error when inserting document 357 Extra data: line 10 column 2 (char 496)
# Error when inserting document 358 'charmap' codec can't decode byte 0x9d in position 571: character maps to <undefined>
# Error when inserting document 359 'charmap' codec can't decode byte 0x9d in position 571: character maps to <undefined>
# Error when inserting document 360 'charmap' codec can't decode byte 0x9d in position 571: character maps to <undefined>
# Inserted document 361
# Error when inserting document 362 Extra data: line 10 column 2 (char 731)
# Error when inserting document 363 Extra data: line 10 column 2 (char 599)
# Error when inserting document 364 Extra data: line 10 column 2 (char 544)
# Error when inserting document 365 Extra data: line 10 column 2 (char 544)
# Inserted document 366
# Inserted document 367
# Error when inserting document 368 Extra data: line 10 column 2 (char 489)
# Error when inserting document 369 Extra data: line 10 column 2 (char 620)
# Inserted document 370
# Error when inserting document 371 Extra data: line 10 column 2 (char 702)
# Inserted document 372
# Error when inserting document 373 Extra data: line 10 column 2 (char 624)
# Inserted document 374
# Error when inserting document 375 Extra data: line 10 column 2 (char 624)
# Error when inserting document 376 Extra data: line 10 column 2 (char 624)
# Inserted document 377
# Error when inserting document 378 Extra data: line 10 column 2 (char 622)
# Inserted document 379
# Error when inserting document 380 Extra data: line 10 column 2 (char 607)
# Error when inserting document 381 Extra data: line 10 column 2 (char 573)
# Error when inserting document 382 Extra data: line 10 column 2 (char 658)
# Error when inserting document 383 Extra data: line 10 column 2 (char 689)
# Inserted document 384
# Error when inserting document 385 Extra data: line 10 column 2 (char 677)
# Error when inserting document 386 Extra data: line 10 column 2 (char 677)
# Inserted document 387
# Error when inserting document 388 Extra data: line 10 column 2 (char 686)
# Inserted document 389
# Error when inserting document 390 Extra data: line 16 column 2 (char 812)
# Error when inserting document 391 Extra data: line 16 column 2 (char 880)
# Error when inserting document 392 Extra data: line 16 column 2 (char 880)
# Inserted document 393
# Error when inserting document 394 Extra data: line 16 column 2 (char 745)
# Inserted document 395
# Error when inserting document 396 'charmap' codec can't decode byte 0x81 in position 665: character maps to <undefined>
# Inserted document 397
# Inserted document 398
# Inserted document 399
# Inserted document 400
# Inserted document 401
# Inserted document 402
# Error when inserting document 403 'charmap' codec can't decode byte 0x81 in position 77: character maps to <undefined>
# Error when inserting document 404 Extra data: line 10 column 2 (char 586)
# Error when inserting document 405 Extra data: line 16 column 2 (char 765)
# Inserted document 406
# Inserted document 407
# Inserted document 408
# Inserted document 409
# Inserted document 410
# Inserted document 411
# Inserted document 412
# Error when inserting document 413 Extra data: line 16 column 2 (char 624)
# Inserted document 414
# Inserted document 415
# Inserted document 416
# Error when inserting document 417 Extra data: line 16 column 2 (char 767)
# Error when inserting document 418 Extra data: line 16 column 2 (char 641)
# Error when inserting document 419 Extra data: line 16 column 2 (char 641)
# Inserted document 420
# Inserted document 421
# Error when inserting document 422 Extra data: line 10 column 2 (char 584)
# Inserted document 423
# Inserted document 424
# Error when inserting document 425 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 426 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 427 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 428 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 429 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 430 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 431 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 432 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 433
# Error when inserting document 434 Extra data: line 10 column 2 (char 588)
# Inserted document 435
# Error when inserting document 436 Extra data: line 10 column 2 (char 588)
# Error when inserting document 437 Extra data: line 10 column 2 (char 588)
# Error when inserting document 438 Extra data: line 10 column 2 (char 588)
# Error when inserting document 439 Extra data: line 10 column 2 (char 588)
# Error when inserting document 440 Extra data: line 10 column 2 (char 588)
# Inserted document 441
# Error when inserting document 442 Extra data: line 10 column 2 (char 588)
# Error when inserting document 443 Extra data: line 10 column 2 (char 588)
# Error when inserting document 444 Extra data: line 10 column 2 (char 588)
# Inserted document 445
# Error when inserting document 446 Extra data: line 10 column 2 (char 588)
# Inserted document 447
# Error when inserting document 448 Extra data: line 10 column 2 (char 588)
# Error when inserting document 449 Extra data: line 10 column 2 (char 588)
# Error when inserting document 450 Extra data: line 10 column 2 (char 588)
# Error when inserting document 451 Extra data: line 10 column 2 (char 588)
# Inserted document 452
# Error when inserting document 453 Extra data: line 10 column 2 (char 588)
# Error when inserting document 454 Extra data: line 10 column 2 (char 588)
# Error when inserting document 455 Extra data: line 10 column 2 (char 588)
# Inserted document 456
# Error when inserting document 457 Extra data: line 10 column 2 (char 588)
# Inserted document 458
# Error when inserting document 459 Extra data: line 10 column 2 (char 588)
# Inserted document 460
# Inserted document 461
# Error when inserting document 462 Extra data: line 10 column 2 (char 661)
# Error when inserting document 463 Extra data: line 10 column 2 (char 672)
# Error when inserting document 464 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 465 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 466 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 467 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 468 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 469 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 470 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 471 'charmap' codec can't decode byte 0x9d in position 372: character maps to <undefined>
# Error when inserting document 472 Extra data: line 10 column 2 (char 696)
# Error when inserting document 473 Extra data: line 10 column 2 (char 696)
# Error when inserting document 474 Extra data: line 10 column 2 (char 696)
# Error when inserting document 475 Extra data: line 10 column 2 (char 696)
# Inserted document 476
# Error when inserting document 477 Extra data: line 10 column 2 (char 604)
# Error when inserting document 478 Extra data: line 10 column 2 (char 604)
# Error when inserting document 479 Extra data: line 10 column 2 (char 604)
# Error when inserting document 480 Extra data: line 10 column 2 (char 604)
# Inserted document 481
# Error when inserting document 482 Extra data: line 10 column 2 (char 531)
# Error when inserting document 483 Extra data: line 10 column 2 (char 583)
# Error when inserting document 484 Extra data: line 10 column 2 (char 583)
# Error when inserting document 485 Extra data: line 10 column 2 (char 583)
# Inserted document 486
# Error when inserting document 487 Extra data: line 10 column 2 (char 583)
# Inserted document 488
# Error when inserting document 489 Extra data: line 10 column 2 (char 681)
# Inserted document 490
# Error when inserting document 491 Extra data: line 10 column 2 (char 681)
# Inserted document 492
# Error when inserting document 493 Extra data: line 10 column 2 (char 681)
# Error when inserting document 494 Extra data: line 10 column 2 (char 681)
# Error when inserting document 495 Extra data: line 10 column 2 (char 681)
# Error when inserting document 496 Extra data: line 10 column 2 (char 681)
# Inserted document 497
# Error when inserting document 498 Extra data: line 10 column 2 (char 681)
# Error when inserting document 499 Extra data: line 10 column 2 (char 681)
# Error when inserting document 500 Extra data: line 10 column 2 (char 681)
# Inserted document 501
# Error when inserting document 502 Extra data: line 10 column 2 (char 698)
# Error when inserting document 503 Extra data: line 10 column 2 (char 698)
# Error when inserting document 504 Extra data: line 10 column 2 (char 698)
# Inserted document 505
# Inserted document 506
# Error when inserting document 507 Extra data: line 10 column 2 (char 727)
# Inserted document 508
# Error when inserting document 509 Extra data: line 10 column 2 (char 727)
# Inserted document 510
# Error when inserting document 511 Extra data: line 10 column 2 (char 628)
# Error when inserting document 512 Extra data: line 10 column 2 (char 628)
# Inserted document 513
# Error when inserting document 514 'charmap' codec can't decode byte 0x9d in position 449: character maps to <undefined>
# Error when inserting document 515 'charmap' codec can't decode byte 0x9d in position 449: character maps to <undefined>
# Error when inserting document 516 'charmap' codec can't decode byte 0x9d in position 449: character maps to <undefined>
# Inserted document 517
# Error when inserting document 518 Extra data: line 10 column 2 (char 580)
# Inserted document 519
# Error when inserting document 520 Extra data: line 10 column 2 (char 613)
# Error when inserting document 521 Extra data: line 10 column 2 (char 613)
# Error when inserting document 522 Extra data: line 10 column 2 (char 586)
# Error when inserting document 523 Extra data: line 10 column 2 (char 586)
# Error when inserting document 524 'charmap' codec can't decode byte 0x8d in position 416: character maps to <undefined>
# Error when inserting document 525 'charmap' codec can't decode byte 0x8d in position 416: character maps to <undefined>
# Error when inserting document 526 'charmap' codec can't decode byte 0x9d in position 521: character maps to <undefined>
# Error when inserting document 527 'charmap' codec can't decode byte 0x9d in position 521: character maps to <undefined>
# Inserted document 528
# Error when inserting document 529 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 530
# Error when inserting document 531 Extra data: line 10 column 2 (char 597)
# Error when inserting document 532 Extra data: line 10 column 2 (char 517)
# Inserted document 533
# Error when inserting document 534 Extra data: line 10 column 2 (char 534)
# Inserted document 535
# Error when inserting document 536 Extra data: line 10 column 2 (char 477)
# Error when inserting document 537 Extra data: line 10 column 2 (char 477)
# Error when inserting document 538 Extra data: line 10 column 2 (char 586)
# Error when inserting document 539 Extra data: line 10 column 2 (char 583)
# Inserted document 540
# Inserted document 541
# Error when inserting document 542 Extra data: line 10 column 2 (char 593)
# Inserted document 543
# Inserted document 544
# Inserted document 545
# Inserted document 546
# Inserted document 547
# Inserted document 548
# Inserted document 549
# Error when inserting document 550 Extra data: line 16 column 2 (char 655)
# Error when inserting document 551 Extra data: line 16 column 2 (char 720)
# Inserted document 552
# Error when inserting document 553 Extra data: line 16 column 2 (char 727)
# Inserted document 554
# Inserted document 555
# Error when inserting document 556 Extra data: line 10 column 2 (char 560)
# Error when inserting document 557 Extra data: line 10 column 2 (char 560)
# Inserted document 558
# Error when inserting document 559 Extra data: line 10 column 2 (char 671)
# Inserted document 560
# Error when inserting document 561 Extra data: line 10 column 2 (char 553)
# Error when inserting document 562 Extra data: line 10 column 2 (char 553)
# Inserted document 563
# Inserted document 564
# Inserted document 565
# Inserted document 566
# Inserted document 567
# Error when inserting document 568 Extra data: line 16 column 2 (char 695)
# Error when inserting document 569 Extra data: line 16 column 2 (char 695)
# Inserted document 570
# Inserted document 571
# Inserted document 572
# Error when inserting document 573 Extra data: line 10 column 2 (char 607)
# Inserted document 574
# Error when inserting document 575 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 576 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 577 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 578 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 579 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 580 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 581
# Inserted document 582
# Inserted document 583
# Inserted document 584
# Error when inserting document 585 Extra data: line 10 column 2 (char 572)
# Error when inserting document 586 Extra data: line 10 column 2 (char 572)
# Error when inserting document 587 'charmap' codec can't decode byte 0x9d in position 406: character maps to <undefined>
# Error when inserting document 588 Extra data: line 10 column 2 (char 307)
# Error when inserting document 589 Extra data: line 10 column 2 (char 485)
# Inserted document 590
# Inserted document 591
# Inserted document 592
# Error when inserting document 593 Extra data: line 10 column 2 (char 565)
# Error when inserting document 594 Extra data: line 10 column 2 (char 510)
# Inserted document 595
# Inserted document 596
# Inserted document 597
# Error when inserting document 598 Extra data: line 10 column 2 (char 565)
# Error when inserting document 599 Extra data: line 10 column 2 (char 577)
# Inserted document 600
# Error when inserting document 601 Extra data: line 10 column 2 (char 616)
# Error when inserting document 602 Extra data: line 10 column 2 (char 493)
# Inserted document 603
# Inserted document 604
# Inserted document 605
# Inserted document 606
# Error when inserting document 607 'charmap' codec can't decode byte 0x9d in position 398: character maps to <undefined>
# Inserted document 608
# Error when inserting document 609 Extra data: line 10 column 2 (char 599)
# Error when inserting document 610 Extra data: line 10 column 2 (char 614)
# Inserted document 611
# Error when inserting document 612 Extra data: line 10 column 2 (char 556)
# Error when inserting document 613 Extra data: line 10 column 2 (char 556)
# Error when inserting document 614 Extra data: line 10 column 2 (char 582)
# Inserted document 615
# Inserted document 616
# Error when inserting document 617 Extra data: line 10 column 2 (char 536)
# Error when inserting document 618 'charmap' codec can't decode byte 0x9d in position 420: character maps to <undefined>
# Inserted document 619
# Inserted document 620
# Error when inserting document 621 Extra data: line 10 column 2 (char 704)
# Error when inserting document 622 Extra data: line 10 column 2 (char 537)
# Inserted document 623
# Error when inserting document 624 Extra data: line 10 column 2 (char 585)
# Inserted document 625
# Inserted document 626
# Inserted document 627
# Error when inserting document 628 Extra data: line 10 column 2 (char 496)
# Error when inserting document 629 Extra data: line 10 column 2 (char 673)
# Inserted document 630
# Inserted document 631
# Error when inserting document 632 Extra data: line 10 column 2 (char 600)
# Inserted document 633
# Error when inserting document 634 Extra data: line 10 column 2 (char 611)
# Error when inserting document 635 Extra data: line 10 column 2 (char 641)
# Inserted document 636
# Inserted document 637
# Inserted document 638
# Inserted document 639
# Error when inserting document 640 Extra data: line 16 column 2 (char 701)
# Error when inserting document 641 Extra data: line 16 column 2 (char 701)
# Inserted document 642
# Inserted document 643
# Error when inserting document 644 Extra data: line 10 column 2 (char 491)
# Error when inserting document 645 Extra data: line 16 column 2 (char 686)
# Error when inserting document 646 Extra data: line 10 column 2 (char 606)
# Inserted document 647
# Inserted document 648
# Inserted document 649
# Inserted document 650
# Error when inserting document 651 Extra data: line 16 column 2 (char 745)
# Error when inserting document 652 Extra data: line 16 column 2 (char 751)
# Error when inserting document 653 Extra data: line 16 column 2 (char 749)
# Error when inserting document 654 Extra data: line 16 column 2 (char 749)
# Error when inserting document 655 'charmap' codec can't decode byte 0x9d in position 560: character maps to <undefined>
# Error when inserting document 656 'charmap' codec can't decode byte 0x9d in position 560: character maps to <undefined>
# Error when inserting document 657 'charmap' codec can't decode byte 0x9d in position 560: character maps to <undefined>
# Inserted document 658
# Error when inserting document 659 'charmap' codec can't decode byte 0x9d in position 593: character maps to <undefined>
# Error when inserting document 660 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 661 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 662 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 663 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 664 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 665 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Error when inserting document 666 document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
# Inserted document 667
# Error when inserting document 668 Extra data: line 10 column 2 (char 363)
# Inserted document 669
# Error when inserting document 670 Extra data: line 10 column 2 (char 615)
# Error when inserting document 671 Extra data: line 10 column 2 (char 532)
# Error when inserting document 672 Extra data: line 10 column 2 (char 488)
# Error when inserting document 673 Extra data: line 10 column 2 (char 657)
# Error when inserting document 674 Extra data: line 10 column 2 (char 400)
# Inserted document 675
# Error when inserting document 676 Extra data: line 10 column 2 (char 713)
# Error when inserting document 677 'charmap' codec can't decode byte 0x81 in position 1961: character maps to <undefined>
# Error when inserting document 678 Extra data: line 10 column 2 (char 599)
# Inserted document 679
# Error when inserting document 680 Extra data: line 10 column 2 (char 604)
# Inserted document 681
# Error when inserting document 682 Extra data: line 10 column 2 (char 622)
# Error when inserting document 683 Extra data: line 10 column 2 (char 446)
# Error when inserting document 684 Extra data: line 10 column 2 (char 616)
# Error when inserting document 685 Extra data: line 10 column 2 (char 636)
# Error when inserting document 686 'charmap' codec can't decode byte 0x9d in position 347: character maps to <undefined>
# Error when inserting document 687 Extra data: line 10 column 2 (char 581)
# Error when inserting document 688 Extra data: line 10 column 2 (char 598)
# Error when inserting document 689 Extra data: line 10 column 2 (char 655)
# Inserted document 690
# Error when inserting document 691 Extra data: line 10 column 2 (char 572)
# Error when inserting document 692 'charmap' codec can't decode byte 0x9d in position 120: character maps to <undefined>
# Error when inserting document 693 Extra data: line 10 column 2 (char 521)
# Error when inserting document 694 'charmap' codec can't decode byte 0x9d in position 120: character maps to <undefined>
# Error when inserting document 695 Extra data: line 10 column 2 (char 557)
# Error when inserting document 696 'charmap' codec can't decode byte 0x81 in position 399: character maps to <undefined>
# Error when inserting document 697 'charmap' codec can't decode byte 0x81 in position 645: character maps to <undefined>
# Error when inserting document 698 'charmap' codec can't decode byte 0x81 in position 558: character maps to <undefined>
# Error when inserting document 699 Extra data: line 10 column 2 (char 463)
# Inserted document 700
# Error when inserting document 701 Extra data: line 10 column 2 (char 513)
# Error when inserting document 702 'charmap' codec can't decode byte 0x9d in position 484: character maps to <undefined>
# Error when inserting document 703 Extra data: line 10 column 2 (char 543)
# ...
# Inserted document 23898
# Inserted document 23899
# Error when inserting document 23900 Extra data: line 46 column 2 (char 1273)
# Error when inserting document 23901 'charmap' codec can't decode byte 0x9d in position 190: character maps to <undefined>
# Error when inserting document 23902 'charmap' codec can't decode byte 0x8d in position 1352: character maps to <undefined>
# Inserted document 23903
# Error when inserting document 23904 'charmap' codec can't decode byte 0x9d in position 449: character maps to <undefined>
# Inserted document 23905
# Error when inserting document 23906 Extra data: line 46 column 2 (char 1116)
# Inserted document 23907
# Error when inserting document 23908 'charmap' codec can't decode byte 0x9d in position 190: character maps to <undefined>
# Error when inserting document 23909 'charmap' codec can't decode byte 0x9d in position 162: character maps to <undefined>
# Error when inserting document 23910 'charmap' codec can't decode byte 0x9d in position 162: character maps to <undefined>
# Error when inserting document 23911 'charmap' codec can't decode byte 0x9d in position 576: character maps to <undefined>
# Inserted document 23912
# Inserted document 23913
# Inserted document 23914
# Inserted document 23915
# Error when inserting document 23916 'charmap' codec can't decode byte 0x8d in position 218: character maps to <undefined>
# Inserted document 23917
# Error when inserting document 23918 'charmap' codec can't decode byte 0x9d in position 441: character maps to <undefined>
# Inserted document 23919
# Error when inserting document 23920 'charmap' codec can't decode byte 0x9d in position 174: character maps to <undefined>
# Inserted document 23921
# Inserted document 23922
# Error when inserting document 23923 Extra data: line 10 column 2 (char 665)
# Error when inserting document 23924 Extra data: line 10 column 2 (char 665)
# Error when inserting document 23925 Extra data: line 10 column 2 (char 665)
# Error when inserting document 23926 Extra data: line 10 column 2 (char 735)
# Error when inserting document 23927 Extra data: line 10 column 2 (char 735)
# Error when inserting document 23928 Extra data: line 10 column 2 (char 735)
# Error when inserting document 23929 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23930 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23931 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23932 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23933 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23934 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23935 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23936 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23937 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23938 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23939 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23940 Extra data: line 10 column 2 (char 675)
# Inserted document 23941
# Error when inserting document 23942 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23943 Extra data: line 10 column 2 (char 675)
# Inserted document 23944
# Error when inserting document 23945 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23946 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23947 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23948 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23949 Extra data: line 10 column 2 (char 675)
# Inserted document 23950
# Inserted document 23951
# Inserted document 23952
# Inserted document 23953
# Inserted document 23954
# Inserted document 23955
# Inserted document 23956
# Error when inserting document 23957 Extra data: line 10 column 2 (char 675)
# Inserted document 23958
# Error when inserting document 23959 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23960 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23961 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23962 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23963 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23964 Extra data: line 10 column 2 (char 675)
# Inserted document 23965
# Error when inserting document 23966 Extra data: line 10 column 2 (char 675)
# Inserted document 23967
# Inserted document 23968
# Error when inserting document 23969 Extra data: line 10 column 2 (char 675)
# Inserted document 23970
# Error when inserting document 23971 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23972 Extra data: line 10 column 2 (char 675)
# Inserted document 23973
# Inserted document 23974
# Inserted document 23975
# Error when inserting document 23976 Extra data: line 10 column 2 (char 675)
# Inserted document 23977
# Inserted document 23978
# Error when inserting document 23979 Extra data: line 10 column 2 (char 675)
# Inserted document 23980
# Inserted document 23981
# Inserted document 23982
# Error when inserting document 23983 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23984 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23985 Extra data: line 10 column 2 (char 675)
# Inserted document 23986
# Error when inserting document 23987 Extra data: line 10 column 2 (char 675)
# Inserted document 23988
# Error when inserting document 23989 Extra data: line 10 column 2 (char 675)
# Error when inserting document 23990 Extra data: line 10 column 2 (char 675)
# Inserted document 23991
# Inserted document 23992
# Inserted document 23993
# Error when inserting document 23994 Extra data: line 10 column 2 (char 669)
# Error when inserting document 23995 Extra data: line 10 column 2 (char 669)
# Error when inserting document 23996 Extra data: line 10 column 2 (char 669)
# Error when inserting document 23997 Extra data: line 10 column 2 (char 669)
# Error when inserting document 23998 Extra data: line 10 column 2 (char 669)
# Error when inserting document 23999 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24000 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24001 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24002 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24003 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24004 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24005 Extra data: line 10 column 2 (char 669)
# Inserted document 24006
# Error when inserting document 24007 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24008 Extra data: line 10 column 2 (char 669)
# Inserted document 24009
# Error when inserting document 24010 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24011 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24012 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24013 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24014 Extra data: line 10 column 2 (char 669)
# Inserted document 24015
# Inserted document 24016
# Inserted document 24017
# Inserted document 24018
# Inserted document 24019
# Inserted document 24020
# Inserted document 24021
# Error when inserting document 24022 Extra data: line 10 column 2 (char 669)
# Inserted document 24023
# Error when inserting document 24024 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24025 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24026 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24027 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24028 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24029 Extra data: line 10 column 2 (char 669)
# Inserted document 24030
# Error when inserting document 24031 Extra data: line 10 column 2 (char 669)
# Inserted document 24032
# Inserted document 24033
# Inserted document 24034
# Inserted document 24035
# Error when inserting document 24036 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24037 Extra data: line 10 column 2 (char 669)
# Inserted document 24038
# Inserted document 24039
# Inserted document 24040
# Error when inserting document 24041 Extra data: line 10 column 2 (char 669)
# Inserted document 24042
# Inserted document 24043
# Error when inserting document 24044 Extra data: line 10 column 2 (char 669)
# Inserted document 24045
# Inserted document 24046
# Inserted document 24047
# Error when inserting document 24048 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24049 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24050 Extra data: line 10 column 2 (char 669)
# Inserted document 24051
# Error when inserting document 24052 Extra data: line 10 column 2 (char 669)
# Inserted document 24053
# Error when inserting document 24054 Extra data: line 10 column 2 (char 669)
# Error when inserting document 24055 Extra data: line 10 column 2 (char 669)
# Inserted document 24056
# Inserted document 24057
# Inserted document 24058
# Error when inserting document 24059 Extra data: line 10 column 2 (char 731)
# Error when inserting document 24060 Extra data: line 10 column 2 (char 731)
# Error when inserting document 24061 Extra data: line 10 column 2 (char 731)
# Error when inserting document 24062 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24063 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24064 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24065 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24066 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24067 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24068 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24069 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24070 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24071 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24072 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24073 Extra data: line 10 column 2 (char 671)
# Inserted document 24074
# Error when inserting document 24075 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24076 Extra data: line 10 column 2 (char 671)
# Inserted document 24077
# Error when inserting document 24078 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24079 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24080 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24081 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24082 Extra data: line 10 column 2 (char 671)
# Inserted document 24083
# Inserted document 24084
# Inserted document 24085
# Inserted document 24086
# Inserted document 24087
# Inserted document 24088
# Inserted document 24089
# Error when inserting document 24090 Extra data: line 10 column 2 (char 671)
# Inserted document 24091
# Error when inserting document 24092 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24093 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24094 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24095 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24096 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24097 Extra data: line 10 column 2 (char 671)
# Inserted document 24098
# Error when inserting document 24099 Extra data: line 10 column 2 (char 671)
# Inserted document 24100
# Inserted document 24101
# Inserted document 24102
# Inserted document 24103
# Error when inserting document 24104 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24105 Extra data: line 10 column 2 (char 671)
# Inserted document 24106
# Inserted document 24107
# Inserted document 24108
# Error when inserting document 24109 Extra data: line 10 column 2 (char 671)
# Inserted document 24110
# Inserted document 24111
# Error when inserting document 24112 Extra data: line 10 column 2 (char 671)
# Inserted document 24113
# Inserted document 24114
# Inserted document 24115
# Error when inserting document 24116 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24117 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24118 Extra data: line 10 column 2 (char 671)
# Inserted document 24119
# Error when inserting document 24120 Extra data: line 10 column 2 (char 671)
# Inserted document 24121
# Error when inserting document 24122 Extra data: line 10 column 2 (char 671)
# Error when inserting document 24123 Extra data: line 10 column 2 (char 671)
# Inserted document 24124
# Inserted document 24125
# Inserted document 24126
# Error when inserting document 24127 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24128 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24129 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24130 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24131 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24132 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24133 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24134 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24135 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24136 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24137 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24138 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24139 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24140 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24141 Extra data: line 10 column 2 (char 672)
# Inserted document 24142
# Error when inserting document 24143 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24144 Extra data: line 10 column 2 (char 672)
# Inserted document 24145
# Error when inserting document 24146 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24147 Extra data: line 10 column 2 (char 672)
# Error when inserting document 24148 Extra data: line 10 column 2 (char 672)
# Inserted document 24149
# Inserted document 24150
# Error when inserting document 24151 Extra data: line 41 column 2 (char 2118)
# Inserted document 24152
# Inserted document 24153
# Error when inserting document 24154 'charmap' codec can't decode byte 0x9d in position 658: character maps to <undefined>
# Error when inserting document 24155 'charmap' codec can't decode byte 0x9d in position 658: character maps to <undefined>
# Error when inserting document 24156 'charmap' codec can't decode byte 0x9d in position 658: character maps to <undefined>
# Error when inserting document 24157 Extra data: line 46 column 2 (char 1528)
# Error when inserting document 24158 Extra data: line 46 column 2 (char 1528)
# Error when inserting document 24159 Extra data: line 46 column 2 (char 1528)
# Inserted document 24160
# Inserted document 24161
# Inserted document 24162
# Inserted document 24163
# Error when inserting document 24164 Extra data: line 56 column 2 (char 1853)
# Error when inserting document 24165 Extra data: line 56 column 2 (char 1853)
# Error when inserting document 24166 Extra data: line 56 column 2 (char 1853)
# Error when inserting document 24167 Extra data: line 56 column 2 (char 1853)
# Inserted document 24168
# Error when inserting document 24169 Extra data: line 56 column 2 (char 1853)
# Inserted document 24170
# Inserted document 24171
# Inserted document 24172
# Error when inserting document 24173 Extra data: line 56 column 2 (char 1850)
# Inserted document 24174
# Inserted document 24175
# Error when inserting document 24176 Extra data: line 10 column 2 (char 288)
